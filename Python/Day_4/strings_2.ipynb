# %% [markdown]
# # More on  strings

# %%
# Remove White spaces:- Whitespace is the space before and/or after the actual text, and very often you want to remove this space.

# Suppose that your name should be written like 
# '               Sudhakar                          Pandit                      '

# %%
mY_name = '               Sudhakar                          Pandit                      '

# %%
mY_name
# Out:
# '               Sudhakar                          Pandit                      '

# %%
mY_name.strip()
# Out:
# 'Sudhakar                          Pandit'

# %%
mY_name
# Out:
# '               Sudhakar                          Pandit                      '

# %% [markdown]
# ## Why this works?
#
# - split() → default whitespace pe split karta hai (multiple spaces ignore karta hai).
#
# - join() → words ko single space se join karta hai.

# %%
clean_name = " ".join(mY_name.split())

# %%
clean_name
# Out:
# 'Sudhakar Pandit'

# %%
First_Name = "Amit"

# %%
Last_Name = "Upadhayay"

# %%
Full_Name = First_Name + Last_Name

print(Full_Name)
# Out:
# AmitUpadhayay

# %%
Full_Name = First_Name +" "+Last_Name

# %%
# + ' ' + ---> Empty String

# %%
Full_Name
# Out:
# 'Amit Upadhayay'

# %%
# Concatenation --- Combining two or more than two strings(texts--str()) together is called Concatenation.

# %%
Msg = "My full name is " + clean_name
Msg
# Out:
# 'My full name isSudhakar Pandit'

# %%
Msg = "My full name is " + clean_name
Msg
# Out:
# 'My full name is Sudhakar Pandit'

# %%
My_Age = 27

# %%
# Msg = "My full name is " + clean_name + My_Age
# Msg

# %%
Msg = "My full name is " + clean_name +' '+ str(My_Age)
Msg
# Out:
# 'My full name is Sudhakar Pandit 27'

# %%
# -f"" -- formatted strings

# %% [markdown]
# My full name is " + clean_name + MY_age, MY marks in Python, Maths, Science, Sst.

# %%
My_Age = 27

# %%
Msg = f"My full name is {clean_name} my age is {My_Age}."

# %%
Msg
# Out:
# 'My full name is Sudhakar Pandit my age is 27.'

# %%
pi = 22/7

# %%
pi
# Out:
# 3.142857142857143

# %%
f"PI has a value of {pi:.2f}."
# Out:
# 'PI has a value of 3.14.'

# %%
txt = "We are the so-called "Vikings" from the north."
# Out:
#   Cell In[44], line 1
#     txt = "We are the so-called "Vikings" from the north."
#                                  ^
# SyntaxError: invalid syntax

# %%
txt = "We are the so-called \"Vikings\" from the north."

# %%
txt
# Out:
# 'We are the so-called "Vikings" from the north.'

# %%
txt = 'We are the so-called "Vikings" from the north.'

# %%
txt
# Out:
# 'We are the so-called "Vikings" from the north.'

# %%
txt = "We are the so-called 'Vikings' from the north."

# %%
txt
# Out:
# "We are the so-called 'Vikings' from the north."
