# %% [markdown]
# # Operators

# %% [markdown]
# 1. Introduction to Operators
# 2. Arithmetic Operators
#    - Addition
#    - Subtraction
#    - Multiplication
#    - Division
#    - Floor Division
#    - Modulus
#    - Exponentiation
# 3. Comparison Operators
#    - Equal to
#    - Not equal to
#    - Greater than
#    - Less than
#    - Greater than or equal to
#    - Less than or equal to
# 4. Logical Operators
#    - AND
#    - OR
#    - NOT
# 5. Practical Examples and Common Errors
#
# Hint-- https://www.geeksforgeeks.org/complete-reference-for-bitwise-operators-in-programming-coding/

# %%
x = 35

y = 7

# %%
print(x+y)
# Out:
# 42

# %%
print(x-y)
print(y-x)
# Out:
# 28
# -28

# %%
print(x * y)
# Out:
# 245

# %%
print(x / y)
# Out:
# 5.0

# %%
# remainder == you have to use modulo(%)
x % y
# Out:
# 0

# %%
12 / 7
# Out:
# 1.7142857142857142

# %%
# Floor divison == quotient but without decimals
12 // 7
# Out:
# 1

# %%
# exponentiation == power 2*2

2 ** 4
# Out:
# 16

# %% [markdown]
# ## H.w == try all these with strings and booleans

# %%
## Arithmethic Operation

a=10
b = 5

add_result=a+b  #addiiton
sub_result=a-b  #substraction 
mult_result=a*b #multiplication
div_result=a/b  #division -- this will always give result in floats.
floor_div_result=a//b ## floor division
modulus_result=a%b #modulus operation

exponent_result=a**b ## Exponentiation


print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_result)

# %% [markdown]
# ## comparison operators
# 1. Equal ==
# 2. Not equal !=
# 3. Greater than	>
# 4. Less than <
# 5. Greater than or equal to	>=
# 6. Less than or equal to <=

# %%
a = 10

b = 5

c = 10

# %%
a == b
# Out:
# False

# %%
c == a
# Out:
# True

# %%
a != c
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
b < c
# Out:
# True

# %%
b <= c
# Out:
# True

# %% [markdown]
# ## Try the same with strings
