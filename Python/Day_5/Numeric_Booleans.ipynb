# %% [markdown]
# ### Numbers -- integer int(), float() - decimal numbers, complex()

# %%
a = 5 # integer

b = 3.7 # float

c = 2 + 3j #complex

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# complex

# %%
a
# Out:
# 5

# %%
float(a)
# Out:
# 5.0

# %%
int(b)
# Out:
# 3

# %%
float(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 float(c)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
complex(a)
# Out:
# (5+0j)

# %%
complex(b)
# Out:
# (3.7+0j)

# %%
str(a)
# Out:
# '5'

# %%
str(b)
# Out:
# '3.7'

# %%
str(c)
# Out:
# '(2+3j)'

# %%
d = "50.78"
type(d)
# Out:
# str

# %%
float(d)
# Out:
# 50.78

# %%
e = "50"
type(e)
# Out:
# str

# %%
int(e)
# Out:
# 50

# %%
print(bool(False))
print(bool(None))
print(bool(0))
print(bool(""))
print(bool(()))
print(bool([]))
print(bool({}))
# Out:
# False
# False
# False
# False
# False
# False
# False

# %%
print(bool(True))
print(bool(2))
print(bool(1))
print(bool("e"))
print(bool(("abhishek",)))
print(bool([1,2.5]))
print(bool({1,2,3}))
# Out:
# True
# True
# True
# True
# True
# True
# True

# %%
bool(15)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True
