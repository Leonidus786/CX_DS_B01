# %%
seller1Name = "A"
seller1Address = "ABC"
seller1Money = 123

# %%
seller2Name = "B"
seller2Address = "DEF"
seller2Money = 456

# %%
seller3Name = "C"
seller3Address = "GFH"
seller3Money = 0

# %%
sellerName = ["A", "B", "C"]

# %%
sellerName[2]
# Out:
# 'C'

# %%
class Dog:
    sound = "bark"

# %%
dog1 = Dog() # Creating object from class
print(dog1.sound) # Accessing the class
# Out:
# bark
