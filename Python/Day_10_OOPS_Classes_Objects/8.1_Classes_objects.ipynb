# %%
import keyword
print(keyword.kwlist)

# %%
class My_first_class:
    x = "Abhi"
    a = 10

# %%
type(My_first_class)

# %%
type(My_first_class)

# %%
my_obj = My_first_class()

# %%
my_obj.x

# %%
my_obj.a
