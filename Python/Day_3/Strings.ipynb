# %% [markdown]
# # Strings

# %% [markdown]
# ## Set of characters, or you can say array of characters.

# %%
Address = "gurugram"  #1st way of declaring a string

Name = 'Swastik'   #2nd way of declaring a string

Name_1 = '''Amit'''  #3rd way of declaring a string

# %%
print(Address)
print(Name)
print(Name_1)
# Out:
# gurugram
# Swastik
# Amit

# %%
len(Address)
# Out:
# 8

# %%
Address[-1]
# Out:
# 'm'

# %%
Address[7]
# Out:
# 'm'

# %%
Address
# Out:
# 'gurugram'

# %%
# Select a part of string by var_name[Start:End:Step]
Address[0:4]
# Out:
# 'guru'

# %%
Address[4:]
# Out:
# 'gram'

# %%
Address[:4]
# Out:
# 'guru'

# %%
Name_1
# Out:
# 'Amit'

# %%
Name_1[::2]
# Out:
# 'Ai'

# %%
nAme = "Abhishek"

# %%
nAme[-4:]
# Out:
# 'shek'

# %%
nAme[:-4]
# Out:
# 'Abhi'

# %%
nAme
# Out:
# 'Abhishek'

# %%
nAme.upper()
# Out:
# 'ABHISHEK'

# %%
nAme.lower()
# Out:
# 'abhishek'
