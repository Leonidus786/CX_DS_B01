# %% [markdown]
# 4. Logical Operators
#    - AND
#    - OR
#    - NOT
# 5. Practical Examples and Common Errors

# %%
c = 0    # 0 - False

b = 1    # 1 - True


x = bool(6)   # True

y = bool("")  # False

# %%
print(x)
print(y)
# Out:
# True
# False

# %%
c and b
# Out:
# 0

# %%
x and y
# Out:
# 0

# %%
x and y
# Out:
# False

# %%
c or b
# Out:
# 1

# %%
18 < 12 and 99 < 100
# Out:
# False

# %%
18 > 12 and 99 < 100
# Out:
# True

# %%
18 < 12 or 99 < 100
# Out:
# True

# %%
c
# Out:
# 0

# %%
not c
# Out:
# True

# %%
not b
# Out:
# False

# %%
a = 25
b = 5

# %% [markdown]
# a < b  : 0
# a > b  : 1
# a <= b: 0
# a >= b: 1
# a == b: 0
# a != b : 1

# %%
print(a < b ) 
print(a > b)  
print(a <= b)
print(a >= b)
print(a == b)
print(a != b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
3 & 2
# Out:
# 2

# %%
6 & 3
# Out:
# 2

# %%
6 | 3
# Out:
# 7

# %%
6 ^ 3
# Out:
# 5

# %% [markdown]
# # ~x = -(x+1)

# %%
~6
# Out:
# -7
