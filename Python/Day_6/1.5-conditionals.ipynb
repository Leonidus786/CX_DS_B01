# %%
a = int(input("Please enter your Number:- "))
type(a)
# Out:
# int

# %%
a
# Out:
# 7728041227

# %%
a = 2

if a == 2 :
    print("yes that's true.")
    print("av mje kro akela hu m.")
# Out:
# yes that's true.
# av mje kro akela hu m.

# %%
a = int(input("Please enter a number.: "))
print(a)

if a >= 10:
    print("a is greater")
else:
    print("do nothing")
# Out:
# -9
# do nothing

# %%
a = -97

# %%
if a ==1:
    print("do this")
elif a == 2:
    print("ab m v chalunga")
elif a >= 2:
    print("Mai v chl skta hu")
else:
    print("Bhaukaal h iska")
# Out:
# Bhaukaal h iska

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
True = 10
# Out:
#   Cell In[28], line 1
#     True = 10
#     ^
# SyntaxError: cannot assign to True

# %%
and = "swastik"
# Out:
#   Cell In[29], line 1
#     and = "swastik"
#     ^
# SyntaxError: invalid syntax

# %%
if, elif, else = 1, 2, 3
# Out:
#   Cell In[30], line 1
#     if, elif, else = 1, 2, 3
#       ^
# SyntaxError: invalid syntax

# %%
True_5 = "swastik"
